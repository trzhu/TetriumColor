# %%
from TetriumColor.Measurement import LoadMetamers
import numpy as np

# %%
spectras = LoadMetamers("../../../measurements/2025-01-22/plate-d-CIVO", "")
[(s*10000).plot(color=(s* 10000).to_rgb()) for s in spectras]
# Out:
# [None, None, None]

# %%
spectras[0].wavelengths[5:-20]
# Out:
# array([ 400.,  404.,  408.,  412.,  416.,  420.,  424.,  428.,  432.,
#         436.,  440.,  444.,  448.,  452.,  456.,  460.,  464.,  468.,
#         472.,  476.,  480.,  484.,  488.,  492.,  496.,  500.,  504.,
#         508.,  512.,  516.,  520.,  524.,  528.,  532.,  536.,  540.,
#         544.,  548.,  552.,  556.,  560.,  564.,  568.,  572.,  576.,
#         580.,  584.,  588.,  592.,  596.,  600.,  604.,  608.,  612.,
#         616.,  620.,  624.,  628.,  632.,  636.,  640.,  644.,  648.,
#         652.,  656.,  660.,  664.,  668.,  672.,  676.,  680.,  684.,
#         688.,  692.,  696.,  700.])

# %%
np.savetxt("spectra_data_0.csv", spectras[0].data[5:-20], delimiter=",")

# %%
np.savetxt("spectra_data_1.csv", spectras[1].data[5:-20], delimiter=",")

# %%
np.savetxt("wavelengths.csv", spectras[0].wavelengths[5:-20].astype(int), delimiter=",", fmt='%s')

# %%
spectras[0].wavelengths[5:-20].astype(int)
# Out:
# array([400, 404, 408, 412, 416, 420, 424, 428, 432, 436, 440, 444, 448,
#        452, 456, 460, 464, 468, 472, 476, 480, 484, 488, 492, 496, 500,
#        504, 508, 512, 516, 520, 524, 528, 532, 536, 540, 544, 548, 552,
#        556, 560, 564, 568, 572, 576, 580, 584, 588, 592, 596, 600, 604,
#        608, 612, 616, 620, 624, 628, 632, 636, 640, 644, 648, 652, 656,
#        660, 664, 668, 672, 676, 680, 684, 688, 692, 696, 700])
